# %%
pip install scapy
# Out:
# Collecting scapy
#   Downloading scapy-2.6.1-py3-none-any.whl (2.4 MB)
# Installing collected packages: scapy
# Successfully installed scapy-2.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from scapy.all import sniff

def packet_callback(packet):
    print("===== New Packet Captured =====")
    print(f"Packet Summary: {packet.summary()}")
    if packet.haslayer("IP"):
        ip_layer = packet["IP"]
        print(f"Source IP: {ip_layer.src}")
        print(f"Destination IP: {ip_layer.dst}")
    if packet.haslayer("TCP"):
        tcp_layer = packet["TCP"]
        print(f"Source Port: {tcp_layer.sport}")
        print(f"Destination Port: {tcp_layer.dport}")
    print("===============================\n")

print("Starting packet sniffing... Press Ctrl+C to stop.")
sniff(prn=packet_callback, count=0)
# Out:
# Starting packet sniffing... Press Ctrl+C to stop.
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44366 > 34.213.91.187:https S
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44366
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 A
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44365 SA
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44365
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44365 > 34.213.91.187:https A
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44365
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44365 > 34.213.91.187:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44365
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44365 > 34.213.91.187:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44365
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44366 SA
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44366
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44366 > 34.213.91.187:https A
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44366
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44366 > 34.213.91.187:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44366
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44366 > 34.213.91.187:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44366
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44365 A
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44365
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44365 A
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44365
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44365 PA / Raw
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44365
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44365 > 34.213.91.187:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44365
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44365 > 34.213.91.187:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44365
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44365 > 34.213.91.187:https A / Raw
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44365
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44365 > 34.213.91.187:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44365
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44365 > 34.213.91.187:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44365
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 PA / Raw
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44366 A
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44366
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44366 A
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44366
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44366 PA / Raw
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44366
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44366 > 34.213.91.187:https PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44366
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44365 A
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44365
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44365 A
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44365
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44365 PA / Raw
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44365
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Qry b'chatgpt.com.'
# Source IP: 192.168.91.252
# Destination IP: 192.168.91.59
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Qry b'chatgpt.com.'
# Source IP: 192.168.91.252
# Destination IP: 192.168.91.59
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Qry b'chatgpt.com.'
# Source IP: 192.168.91.252
# Destination IP: 192.168.91.59
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Ans 172.64.155.209
# Source IP: 192.168.91.59
# Destination IP: 192.168.91.252
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Ans
# Source IP: 192.168.91.59
# Destination IP: 192.168.91.252
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44365 > 34.213.91.187:https A
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44365
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Ans 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4
# Source IP: 192.168.91.59
# Destination IP: 192.168.91.252
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https S
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 SA
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https PA / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https PA / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https PA / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https PA / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https PA / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https PA / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https PA / Raw
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44366 A
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44366
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 A / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 PA / Raw
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44366 > 34.213.91.187:https FA
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44366
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44365 > 34.213.91.187:https FA
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44365
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https FA
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https FA
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 FA
# Source Port: 443
# Destination Port: 44367
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44367 > 2606:4700:83b2:7cbc:c23b:5:5ff2:75c4:https A
# Source Port: 44367
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44364 FA
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44364
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44364 > 108.159.15.24:https A
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44364
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Qry b'ab.chatgpt.com.'
# Source IP: 192.168.91.252
# Destination IP: 192.168.91.59
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Qry b'ab.chatgpt.com.'
# Source IP: 192.168.91.252
# Destination IP: 192.168.91.59
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Qry b'ab.chatgpt.com.'
# Source IP: 192.168.91.252
# Destination IP: 192.168.91.59
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Ans 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4
# Source IP: 192.168.91.59
# Destination IP: 192.168.91.252
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Ans 172.64.155.209
# Source IP: 192.168.91.59
# Destination IP: 192.168.91.252
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP / DNS Ans
# Source IP: 192.168.91.59
# Destination IP: 192.168.91.252
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https S
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 SA
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https PA / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 A
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 A
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 A / Raw
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 A / Raw
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 PA / Raw
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https PA / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https PA / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https PA / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44365 PA / Raw
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44365
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44365 FA
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44365
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44365 > 34.213.91.187:https RA
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44365
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44366 PA / Raw
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44366
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44366 > 34.213.91.187:https RA
# Source IP: 192.168.91.252
# Destination IP: 34.213.91.187
# Source Port: 44366
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.213.91.187:https > 192.168.91.252:44366 FA
# Source IP: 34.213.91.187
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44366
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 PA / Raw
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 A
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 PA / Raw
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 A
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 A
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https PA / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 A
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 A
# Source Port: 443
# Destination Port: 44368
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44368 > 2606:4700:83b2:7cbc:c2fe:5:5ff2:75c4:https A / Raw
# Source Port: 44368
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# ...
# Source Port: 443
# Destination Port: 44544
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:240:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44544 FA
# Source Port: 443
# Destination Port: 44544
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44544 > 2404:a800:6:240:face:b00c:3333:7020:https A
# Source Port: 44544
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:240:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44544 FA
# Source Port: 443
# Destination Port: 44544
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44544 > 2404:a800:6:240:face:b00c:3333:7020:https A
# Source Port: 44544
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:129:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44542 PA / Raw
# Source Port: 443
# Destination Port: 44542
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:129:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44542 FA
# Source Port: 443
# Destination Port: 44542
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:129:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44542 FA
# Source Port: 443
# Destination Port: 44542
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44542 > 2404:a800:6:129:face:b00c:3333:7020:https A
# Source Port: 44542
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:127:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44539 PA / Raw
# Source Port: 443
# Destination Port: 44539
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44539 > 2404:a800:6:127:face:b00c:3333:7020:https A
# Source Port: 44539
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:127:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44539 FA
# Source Port: 443
# Destination Port: 44539
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:127:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44539 FA
# Source Port: 443
# Destination Port: 44539
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44539 > 2404:a800:6:127:face:b00c:3333:7020:https A
# Source Port: 44539
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44694 > 34.205.61.22:https FA
# Source IP: 192.168.91.252
# Destination IP: 34.205.61.22
# Source Port: 44694
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44691 > 34.139.124.58:https FA
# Source IP: 192.168.91.252
# Destination IP: 34.139.124.58
# Source Port: 44691
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44692 > 34.205.61.22:https FA
# Source IP: 192.168.91.252
# Destination IP: 34.205.61.22
# Source Port: 44692
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44696 > 108.159.15.24:https FA
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44696
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44690 > 34.139.124.58:https FA
# Source IP: 192.168.91.252
# Destination IP: 34.139.124.58
# Source Port: 44690
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 108.159.15.24:https > 192.168.91.252:44696 FA
# Source IP: 108.159.15.24
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44696
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44696 > 108.159.15.24:https A
# Source IP: 192.168.91.252
# Destination IP: 108.159.15.24
# Source Port: 44696
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:224:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44546 PA / Raw
# Source Port: 443
# Destination Port: 44546
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:224:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44546 FA
# Source Port: 443
# Destination Port: 44546
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44546 > 2404:a800:6:224:face:b00c:3333:7020:https A
# Source Port: 44546
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:126:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44540 PA / Raw
# Source Port: 443
# Destination Port: 44540
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:126:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44540 FA
# Source Port: 443
# Destination Port: 44540
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44540 > 2404:a800:6:126:face:b00c:3333:7020:https A
# Source Port: 44540
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.205.61.22:https > 192.168.91.252:44694 PA / Raw
# Source IP: 34.205.61.22
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44694
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.205.61.22:https > 192.168.91.252:44694 FA
# Source IP: 34.205.61.22
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44694
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44694 > 34.205.61.22:https RA
# Source IP: 192.168.91.252
# Destination IP: 34.205.61.22
# Source Port: 44694
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.139.124.58:https > 192.168.91.252:44691 FA
# Source IP: 34.139.124.58
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44691
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44691 > 34.139.124.58:https A
# Source IP: 192.168.91.252
# Destination IP: 34.139.124.58
# Source Port: 44691
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.205.61.22:https > 192.168.91.252:44692 PA / Raw
# Source IP: 34.205.61.22
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44692
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.205.61.22:https > 192.168.91.252:44692 FA
# Source IP: 34.205.61.22
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44692
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44692 > 34.205.61.22:https RA
# Source IP: 192.168.91.252
# Destination IP: 34.205.61.22
# Source Port: 44692
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 34.139.124.58:https > 192.168.91.252:44690 FA
# Source IP: 34.139.124.58
# Destination IP: 192.168.91.252
# Source Port: 443
# Destination Port: 44690
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44690 > 34.139.124.58:https A
# Source IP: 192.168.91.252
# Destination IP: 34.139.124.58
# Source Port: 44690
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:128:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44543 PA / Raw
# Source Port: 443
# Destination Port: 44543
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:128:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44543 FA
# Source Port: 443
# Destination Port: 44543
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44543 > 2404:a800:6:128:face:b00c:3333:7020:https A
# Source Port: 44543
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / UDP 192.168.91.59:57621 > 192.168.91.255:57621 / Raw
# Source IP: 192.168.91.59
# Destination IP: 192.168.91.255
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44546 > 2404:a800:6:224:face:b00c:3333:7020:https FA
# Source Port: 44546
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44539 > 2404:a800:6:127:face:b00c:3333:7020:https FA
# Source Port: 44539
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:224:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44546 A
# Source Port: 443
# Destination Port: 44546
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:127:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44539 A
# Source Port: 443
# Destination Port: 44539
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44543 > 2404:a800:6:128:face:b00c:3333:7020:https FA
# Source Port: 44543
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:128:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44543 A
# Source Port: 443
# Destination Port: 44543
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44544 > 2404:a800:6:240:face:b00c:3333:7020:https FA
# Source Port: 44544
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:240:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44544 A
# Source Port: 443
# Destination Port: 44544
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44542 > 2404:a800:6:129:face:b00c:3333:7020:https FA
# Source Port: 44542
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:129:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44542 A
# Source Port: 443
# Destination Port: 44542
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44524 > 2404:a800:6:8c:face:b00c:3333:7020:https FA
# Source Port: 44524
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44540 > 2404:a800:6:126:face:b00c:3333:7020:https FA
# Source Port: 44540
# Destination Port: 443
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:8c:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44524 A
# Source Port: 443
# Destination Port: 44524
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / TCP 2404:a800:6:126:face:b00c:3333:7020:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:44540 A
# Source Port: 443
# Destination Port: 44540
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 > 2404:6800:4007:802::200e:https / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 > 2404:6800:4007:802::200e:https / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2404:6800:4007:802::200e:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2404:6800:4007:802::200e:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 > 2404:6800:4007:802::200e:https / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 > 2404:6800:4007:802::200e:https / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2404:6800:4007:802::200e:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2404:6800:4007:802::200e:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 > 2404:6800:4007:802::200e:https / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 > 2404:6800:4007:802::200e:https / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2404:6800:4007:802::200e:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IPv6 / UDP 2404:6800:4007:802::200e:https > 2401:4900:2300:1acf:1c34:a397:ed1:37cf:64906 / Raw
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44525 > 163.70.139.61:http PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 163.70.139.61
# Source Port: 44525
# Destination Port: 80
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 163.70.139.61:http > 192.168.91.252:44525 A
# Source IP: 163.70.139.61
# Destination IP: 192.168.91.252
# Source Port: 80
# Destination Port: 44525
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 192.168.91.252:44525 > 163.70.139.61:http PA / Raw
# Source IP: 192.168.91.252
# Destination IP: 163.70.139.61
# Source Port: 44525
# Destination Port: 80
# ===============================
#
# ===== New Packet Captured =====
# Packet Summary: Ether / IP / TCP 163.70.139.61:http > 192.168.91.252:44525 A
# Source IP: 163.70.139.61
# Destination IP: 192.168.91.252
# Source Port: 80
# Destination Port: 44525
# ===============================
# <Sniffed: TCP:8374 UDP:402 ICMP:0 Other:59>

# %%
import threading
import tkinter as tk
from tkinter import scrolledtext, ttk
from scapy.all import sniff, get_if_list

def packet_callback(packet):
    output = "===== New Packet Captured =====\n"
    output += f"Packet Summary: {packet.summary()}\n"
    if packet.haslayer("IP"):
        ip_layer = packet["IP"]
        output += f"Source IP: {ip_layer.src}\n"
        output += f"Destination IP: {ip_layer.dst}\n"
    if packet.haslayer("TCP"):
        tcp_layer = packet["TCP"]
        output += f"Source Port: {tcp_layer.sport}\n"
        output += f"Destination Port: {tcp_layer.dport}\n"
    output += "===============================\n\n"
    output_area.insert(tk.END, output)
    output_area.see(tk.END)

def start_sniffing():
    selected_interface = interface_combo.get()
    if not selected_interface:
        output_area.insert(tk.END, "⚠️ Please select a network interface.\n")
        return
    output_area.insert(tk.END, f"🔍 Sniffing started on interface: {selected_interface}\n\n")
    sniff_thread = threading.Thread(
        target=sniff, kwargs={"iface": selected_interface, "prn": packet_callback, "count": 0}
    )
    sniff_thread.daemon = True
    sniff_thread.start()

window = tk.Tk()
window.title("Packet Sniffer (Beginner GUI with Interface Selector)")
window.geometry("750x550")

tk.Label(window, text="Select Network Interface:", font=("Arial", 12)).pack(pady=(10, 0))
interface_combo = ttk.Combobox(window, values=get_if_list(), width=50, font=("Arial", 10))
interface_combo.pack(pady=5)

output_area = scrolledtext.ScrolledText(window, wrap=tk.WORD, width=90, height=25, font=("Consolas", 10))
output_area.pack(pady=10)

start_button = tk.Button(window, text="Start Sniffing", command=start_sniffing, bg="green", fg="white", font=("Arial", 12, "bold"))
start_button.pack(pady=10)

window.mainloop()
